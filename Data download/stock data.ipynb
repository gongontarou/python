# %%
# !pip install pandas-datareader
# !pip install --upgrade pip
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.8.1-py2.py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: lxml in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from pandas-datareader) (4.5.0)
# Requirement already satisfied: pandas>=0.21 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from pandas-datareader) (1.0.3)
# Requirement already satisfied: requests>=2.3.0 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from pandas-datareader) (2.23.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader) (1.18.4)
# Requirement already satisfied: pytz>=2017.2 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas-datareader) (1.14.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.8.1
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/Users/nakamuratatsuya/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# 米国の上場投資信託(ETF)のusmvです。

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt #描画ライブラリ
import pandas_datareader.data as web #データのダウンロードライブラリ
tsd = web.DataReader("usmv","yahoo","1980/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()
# Out:
# /Users/nakamuratatsuya/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ダウジョーンズ

# %%
tsd = web.DataReader("dia","yahoo","1980/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()

# %% [markdown]
# ナスダック100

# %%
tsd = web.DataReader("qqq","yahoo","1980/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()

# %% [markdown]
# 日経225

# %%
tsd = web.DataReader("^N225","yahoo","2010/1/1").dropna()#jpy
tsd.loc[:,'Adj Close'].plot()
tsd.to_csv("tsd.csv")

# %%
import pandas as pd
df = pd.read_csv("tsd.csv")

#print(df.head())
#print(df.tail())
#print (df)
